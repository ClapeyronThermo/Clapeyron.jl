# %%
using Pkg,Plots
Pkg.activate("..")
using JuliaSAFT
# Out:
# Activating environment at `~/Documents/University/UROP/SAFT codes/JuliaSAFT/Project.toml`
# ┌ Info: Precompiling JuliaSAFT [ad2bf161-b011-4a42-8437-67ec766fa70d]
# └ @ Base loading.jl:1273

# %% [markdown]
# In this notebook we will try to replicate various figures from J. Gross and G. Sadowski's 2001 paper

# %% [markdown]
# ## Figure 3

# %%
# Setting up the models
methane      = system(["methane"],"PCSAFT")
propylene    = system(["propylene"],"PCSAFT")
toluene      = system(["toluene"],"PCSAFT")
diethylether = system(["diethyl ether"],"PCSAFT");

# %%
# Get critical point for all species
(T_c_methane, p_c_methane, v_c_methane)                = get_Pcrit(methane)
(T_c_propylene, p_c_propylene, v_c_propylene)          = get_Pcrit(propylene)
(T_c_toluene, p_c_toluene, v_c_toluene)                = get_Pcrit(toluene)
(T_c_diethylether, p_c_diethylether, v_c_diethylether) = get_Pcrit(diethylether);

# %%
# Get saturation properties for all species
T_methane      = range(100, T_c_methane, length = 100)
T_propylene    = range(120, T_c_propylene, length = 100)
T_toluene      = range(170, T_c_toluene, length = 100)
T_diethylether = range(150, T_c_diethylether, length = 100)

(P_sat_methane, v_l_methane, v_v_methane)                = get_Psat(methane,T_methane)
(P_sat_propylene, v_l_propylene, v_v_propylene)          = get_Psat(propylene,T_propylene)
(P_sat_toluene, v_l_toluene, v_v_toluene)                = get_Psat(toluene,T_toluene)
(P_sat_diethylether, v_l_diethylether, v_v_diethylether) = get_Psat(diethylether,T_diethylether);

# %%
plt = plot(0.016 ./v_l_methane, T_methane,color=:red,xlabel="Density / kg/m³",ylabel="T / K", label = "methane")
plt = plot!(0.016 ./v_v_methane, T_methane,color=:red, label = "")
plt = plot!(0.042 ./v_l_propylene, T_propylene,color=:blue, label = "propylene")
plt = plot!(0.042 ./v_v_propylene, T_propylene,color=:blue, label = "")
plt = plot!(0.092 ./v_l_toluene, T_toluene,color=:green, label = "toluene")
plt = plot!(0.092 ./v_v_toluene, T_toluene,color=:green, label = "")
plt = plot!(0.074 ./v_l_diethylether, T_diethylether,color=:purple, label = "diethyl ether")
plt = plot!(0.074 ./v_v_diethylether, T_diethylether,color=:purple, label = "")
display(plt)

# %% [markdown]
# ## Figure 4

# %%
# Setting up the models
CO2      = system(["carbon dioxide"],"PCSAFT");

# %%
# Get critical point
(T_c_CO2, p_c_CO2, v_c_CO2) = get_Pcrit(CO2);

# %%
# Get saturation properties
T_CO2      = range(220, T_c_CO2, length = 100)

(P_sat_CO2, v_l_CO2, v_v_CO2) = get_Psat(CO2,T_CO2);

# %%
# Get various isobars
p = 10 .^(5 .+range(0.7,3,length=200))
z = create_z(CO2,[1.0])
v_1 = []
v_2 = []
v_3 = []
v_4 = []
for i in p
    append!(v_1,get_volume(CO2,z,i,320))
    append!(v_2,get_volume(CO2,z,i,400))
    append!(v_3,get_volume(CO2,z,i,300))
    append!(v_4,get_volume(CO2,z,i,270))
end

# %%
plt = plot(0.044 ./v_l_CO2, P_sat_CO2/1e5,xaxis=:log,yaxis=:log,color=:black,xlabel="Density / kg/m³",ylabel="P / bar", label = "")
plt = plot!(0.044 ./v_v_CO2, P_sat_CO2/1e5,color=:black, label = "")
plt = plot!(0.044 ./v_1, p/1e5,color=:red, label = "")
plt = plot!(0.044 ./v_2, p/1e5,color=:blue, label = "")
plt = plot!(0.044 ./v_3, p/1e5,color=:green, label = "")
plt = plot!(0.044 ./v_4, p/1e5,color=:purple, label = "")
display(plt)

# %% [markdown]
# ## Figure 6

# %%
# Setting up the models
benzene      = system(["benzene"],"PCSAFT")
isobutane    = system(["isobutane"],"PCSAFT");

# %%
(T_c_benzene, p_c_benzene, v_c_benzene)       = get_Pcrit(benzene)
(T_c_isobutane, p_c_isobutane, v_c_isobutane) = get_Pcrit(isobutane);

# %%
# Get enthalpies of vapourisation
h_vap_benzene   = get_enthalpy_vap(benzene,T_c_benzene*range(0.5,1,length=100))
h_vap_propylene = get_enthalpy_vap(propylene,T_c_propylene*range(0.3,1,length=100))
h_vap_isobutane = get_enthalpy_vap(isobutane,T_c_isobutane*range(0.3,1,length=100))
# Out:
# DomainError with -0.36104194290072544:
# log will only return a complex result if called with a complex argument. Try log(Complex(x)).
#
# Stacktrace:
#  [1] throw_complex_domainerror(::Symbol, ::Float64) at ./math.jl:32
#  [2] log(::Float64) at ./special/log.jl:285
#  [3] log(::ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2}) at /Users/pierrewalker/.julia/packages/ForwardDiff/sdToQ/src/dual.jl:203
#  [4] a_hs(::JuliaSAFT.PCSAFT, ::NamedArrays.NamedArray{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1,Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1},Tuple{OrderedCollections.OrderedDict{Set{String},Int64}}}, ::ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2}, ::Float64) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/eos/SAFT/PCSAFT.jl:44
#  [5] a_hc(::JuliaSAFT.PCSAFT, ::NamedArrays.NamedArray{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1,Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1},Tuple{OrderedCollections.OrderedDict{Set{String},Int64}}}, ::ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2}, ::Float64) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/eos/SAFT/PCSAFT.jl:9
#  [6] a_res(::JuliaSAFT.PCSAFT, ::NamedArrays.NamedArray{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1,Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1},Tuple{OrderedCollections.OrderedDict{Set{String},Int64}}}, ::ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2}, ::Float64) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/eos/SAFT/PCSAFT.jl:2
#  [7] eos(::JuliaSAFT.PCSAFT, ::NamedArrays.NamedArray{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1,Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1},Tuple{OrderedCollections.OrderedDict{Set{String},Int64}}}, ::ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2}, ::Float64) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/eos/eos.jl:2
#  [8] (::JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64})(::Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1}) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/getproperties_SAFT.jl:63
#  [9] vector_mode_gradient(::JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64}, ::Array{Float64,1}, ::ForwardDiff.GradientConfig{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2,Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1}}) at /Users/pierrewalker/.julia/packages/ForwardDiff/sdToQ/src/apiutils.jl:37
#  [10] gradient(::Function, ::Array{Float64,1}, ::ForwardDiff.GradientConfig{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2,Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1}}, ::Val{true}) at /Users/pierrewalker/.julia/packages/ForwardDiff/sdToQ/src/gradient.jl:17
#  [11] gradient(::Function, ::Array{Float64,1}, ::ForwardDiff.GradientConfig{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2,Array{ForwardDiff.Dual{ForwardDiff.Tag{JuliaSAFT.var"#fun#344"{JuliaSAFT.PCSAFT,Float64},Float64},Float64,2},1}}) at /Users/pierrewalker/.julia/packages/ForwardDiff/sdToQ/src/gradient.jl:15 (repeats 2 times)
#  [12] df at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/getproperties_SAFT.jl:64 [inlined]
#  [13] Obj_Sat(::JuliaSAFT.PCSAFT, ::Array{Float64,1}, ::Float64, ::Float64, ::Float64) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/getproperties_SAFT.jl:65
#  [14] (::JuliaSAFT.var"#340#342"{JuliaSAFT.PCSAFT,StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}},Int64})(::Array{Float64,1}, ::Array{Float64,1}) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/getproperties_SAFT.jl:50
#  [15] value!!(::NLSolversBase.OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}, ::Array{Float64,1}) at /Users/pierrewalker/.julia/packages/NLSolversBase/5oIMo/src/interface.jl:166
#  [16] value!! at /Users/pierrewalker/.julia/packages/NLSolversBase/5oIMo/src/interface.jl:164 [inlined]
#  [17] value! at /Users/pierrewalker/.julia/packages/NLSolversBase/5oIMo/src/interface.jl:28 [inlined]
#  [18] trust_region_(::NLSolversBase.OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::Float64, ::Bool, ::NLsolve.NewtonTrustRegionCache{Array{Float64,1}}) at /Users/pierrewalker/.julia/packages/NLsolve/04rfI/src/solvers/trust_region.jl:174
#  [19] trust_region at /Users/pierrewalker/.julia/packages/NLsolve/04rfI/src/solvers/trust_region.jl:235 [inlined] (repeats 2 times)
#  [20] #nlsolve#25(::Symbol, ::Float64, ::Float64, ::Int64, ::Bool, ::Bool, ::Bool, ::LineSearches.Static, ::NLsolve.var"#26#28", ::Float64, ::Bool, ::Int64, ::Int64, ::Int64, ::Float64, ::typeof(NLsolve.nlsolve), ::NLSolversBase.OnceDifferentiable{Array{Float64,1},Array{Float64,2},Array{Float64,1}}, ::Array{Float64,1}) at /Users/pierrewalker/.julia/packages/NLsolve/04rfI/src/nlsolve/nlsolve.jl:26
#  [21] nlsolve at /Users/pierrewalker/.julia/packages/NLsolve/04rfI/src/nlsolve/nlsolve.jl:18 [inlined]
#  [22] #nlsolve#31(::Bool, ::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::typeof(NLsolve.nlsolve), ::Function, ::Function, ::Array{Float64,1}) at /Users/pierrewalker/.julia/packages/NLsolve/04rfI/src/nlsolve/nlsolve.jl:67
#  [23] nlsolve(::Function, ::Function, ::Array{Float64,1}) at /Users/pierrewalker/.julia/packages/NLsolve/04rfI/src/nlsolve/nlsolve.jl:61
#  [24] get_Psat(::JuliaSAFT.PCSAFT, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/getproperties_SAFT.jl:52
#  [25] get_enthalpy_vap(::JuliaSAFT.PCSAFT, ::StepRangeLen{Float64,Base.TwicePrecision{Float64},Base.TwicePrecision{Float64}}) at /Users/pierrewalker/Documents/University/UROP/SAFT codes/JuliaSAFT/src/methods/getproperties_SAFT.jl:117
#  [26] top-level scope at In[13]:3

# %%
plt = plot(range(0.5,1,length=100), h_vap_benzene,color=:green,xlabel="T / T/m³",ylabel="P / bar", label = "")
plt = plot!(0.044 ./v_v_CO2, P_sat_CO2/1e5,color=:black, label = "")
plt = plot!(0.044 ./v_1, p/1e5,color=:red, label = "")
plt = plot!(0.044 ./v_2, p/1e5,color=:blue, label = "")
plt = plot!(0.044 ./v_3, p/1e5,color=:green, label = "")
plt = plot!(0.044 ./v_4, p/1e5,color=:purple, label = "")
