# %%
using Pkg,Plots
Pkg.activate("..")
using JuliaSAFT
# Out:
# Activating environment at `~/Documents/University/UROP/SAFT codes/JuliaSAFT/Project.toml`

# %% [markdown]
# In this notebook we will try to replicate various figures from J. Gross and G. Sadowski's 2002 paper

# %% [markdown]
# ## Figure 1

# %%
# Setting up the models
methanol = system(["methanol"],"PCSAFT")
pentanol = system(["1-pentanol"],"PCSAFT")
nonanol  = system(["1-nonanol"],"PCSAFT");
# Out:
# JuliaSAFT.PCSAFT(Set{String}[Set(["1-nonanol"])], JuliaSAFT.PCSAFTParams(Dict(Set(["1-nonanol"]) => 4.6839), Dict(Set(["1-nonanol"]) => 3.7292000000000004e-10), Dict(Set(["1-nonanol"]) => 263.64), Dict(Set([(Set(["1-nonanol"]), "H"), (Set(["1-nonanol"]), "e")]) => 2941.9), Dict(Set([(Set(["1-nonanol"]), "H"), (Set(["1-nonanol"]), "e")]) => 0.001427), Dict{Any,Any}(Set(["1-nonanol"]) => Dict{Any,Any}("e" => 1.0,"H" => 1.0))))

# %%
# Get critical point for all species
(T_c_methanol, p_c_methanol, v_c_methanol) = get_Pcrit(methanol)
(T_c_pentanol, p_c_pentanol, v_c_pentanol) = get_Pcrit(pentanol)
(T_c_nonanol, p_c_nonanol, v_c_nonanol)    = get_Pcrit(nonanol);
# Out:
# (686.8130974077912, 3.0864662529419647e6, 0.0005659231998563467)

# %%
# Get saturation properties for all species
T_methanol = range(205, T_c_methanol, length = 100)
T_pentanol = range(220, T_c_pentanol, length = 100)
T_nonanol  = range(280, T_c_nonanol, length = 100)

(P_sat_methanol, v_l_methanol, v_v_methanol) = get_Psat(methanol,T_methanol)
(P_sat_pentanol, v_l_pentanol, v_v_pentanol) = get_Psat(pentanol,T_pentanol)
(P_sat_nonanol, v_l_nonanol, v_v_nonanol)    = get_Psat(nonanol,T_nonanol);

# %%
plt = plot(0.032 ./v_l_methanol, T_methanol,color=:red,xlabel="Density / kg/m³",ylabel="T / K", label = "methanol")
plt = plot!(0.032 ./v_v_methanol, T_methanol,color=:red, label = "")
plt = plot!(0.088 ./v_l_pentanol, T_pentanol,color=:blue, label = "pentanol")
plt = plot!(0.088 ./v_v_pentanol, T_pentanol,color=:blue, label = "")
plt = plot!(0.144 ./v_l_nonanol, T_nonanol,color=:green, label = "nonanol")
plt = plot!(0.144 ./v_v_nonanol, T_nonanol,color=:green, label = "")
display(plt)
